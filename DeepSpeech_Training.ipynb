# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
import pandas as pd
from fuzzywuzzy import fuzz
import nltk
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# /usr/local/lib/python3.7/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from random import randint
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
# !ls "/content/drive/"
# Out:
# 'AFLL Assignment2_PES2UG20CS186_Maneesh_C Sec.docx.pdf'
# 'AFLL Assignment2_PES2UG20CS194_SANJANA.M_C Sec.docx-converted.gdoc'
# 'AFLL Assignment2_PES2UG20CS194_SANJANA.M_C Sec.docx-converted.pdf'
# 'Anjali kesanapalli cs week4 (3).gdoc'
#  ASSIGNMENT-2.docx
#  ASSIGNMENT-2.gdoc
#  ASSIGNMENT-2_PES2UG20CS186.docx
#  ASSIGNMENT-2_PES2UG20CS186.pdf
#  bScaspks
# 'CamScanner 01-06-2021 07.21.37.pdf'
# 'certificate (1).pdf'
# 'chemistry experiment 1.pdf'
#  Classroom
# 'Colab Notebooks'
# '[Content_Types].xml.gdoc'
#  CS186_MANEESH_AFLL_unit3.mp4
# "DDCO LAB2_PES2UG20CS194_SANJANA MEKALA_'C' Sec-converted.gdoc"
# 'DDCOLAB6_PES2UG20CS158_KATTA LOHITH KRISHNA KUMAR_C-converted.gdoc'
#  DDCO_WEEK-5.DOCX
#  DDCO_WEEK-5.gdoc
# 'EC __TEST.pdf'
# 'Exp2_PES2UG20CS186 (1).pdf'
#  Exp2_PES2UG20CS186.pdf
#  file1_1612028753883.pdf
#  ftp.txt
# 'iht-njjq-ghv - Jan 1, 2022.gjam'
#  IMG_20210509_103021.jpg
#  IMG_20210520_201807.jpg
#  IMG_20210525_193611.jpg
# 'IMG_20210622_114515 (1).jpg'
#  IMG_20210622_114515.jpg
#  IMG_20210706_184055.jpg
# 'IMG_20210725_125135 (1).jpg'
#  IMG_20210725_125135.jpg
#  IMG_20210725_125135.pdf
#  IMG_20210726_115226.jpg
#  IMG_20210916_153130_415.jpg
#  IMG-20210929-WA0016.jpg
#  Indian-Accent-Speech-Recognition-master
# 'K.Maneesh nand reddy_PES2UG20CS186_C Sec WEEK 6.C-converted.gdoc'
# 'K.Maneesh nand reddy_PES2UG20CS186_C Sec WEEK 6.C-converted.pdf'
# 'Maneesh Nand Reddy'
# 'Matlab SEM-2.gdoc'
#  PES2U20CS200_Week-7_Mohamed-Ayaan.gdoc
#  PES2UG20CS186_AFLL_UNIT5-converted.pdf
#  PES2UG20CS186_C_afll_unit1-converted.pdf
#  PES2UG20CS186_EC_assignment.pdf
# 'PES2UG20CS186_K_maneesh nand reddy_C section_DDCO ASSIGNMENT SET8.pdf'
# 'PES2UG20CS186.WEB TECH ASSINGNEMENT 3-converted.pdf'
#  PES2UG20CS186.zip
#  PES2UG20CS86_week3_MPCA.gdoc
# 'possible viva questions (1).gdoc'
# 'possible viva questions (2).gdoc'
# 'possible viva questions.gdoc'
# 'Practice Questions.docx'
# 'Rithvik .k (MEEB-13995) (1).pdf'
# 'Rithvik .k (MEEB-13995).pdf'
# "Rithvik's "
# 'SANJANA.M_PES2UG20CS194_C Sec WEEK 6.C-converted.gdoc'
#  Screenshot_20210707_165810.jpg
#  Snapchat-447818911.jpg
# 'Untitled document.gdoc'
#  webchat.txt
# 'Week 2 - Cisco Packet Tracer 1 - IPv4 Static Addressing and Routing.docx'
# 'WhatsApp Chat with 🙈 JAATHI  🙉 RATNALU 🙊 (1).gdoc'
# 'WhatsApp Chat with 🙈 JAATHI  🙉 RATNALU 🙊 (2).gdoc'
# 'WhatsApp Chat with 🙈 JAATHI  🙉 RATNALU 🙊 (3).gdoc'
# 'WhatsApp Chat with 🙈 JAATHI  🙉 RATNALU 🙊.gdoc'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/Flickr8k_Dataset/Flicker8k_Dataset/
# Out:
# /content/drive/My Drive/Flickr8k_Dataset/Flicker8k_Dataset

# %%
def texter(text):
  final_search = pd.read_csv('/content/drive/MyDrive/final_captions_24_02_20.csv')
  n = len(final_search)
  a = []
  for i in range(n):
    a.append(text)
  final_search['data'] = a
  def get_ratio(final_search):
    name = final_search['captions']
    name1 = final_search['data']
    return fuzz.token_set_ratio(name, name1)
  data = final_search[final_search.apply(get_ratio,axis=1)>80]
  conf = data['image_id']
  cb1 = list(conf)
  g = len(conf)
  n = randint(1,g)
  plt.figure(figsize=(150,150))
  for i in range(n):
    plt.subplot(n,30,i+1)
    build = img.imread(cb1[i])
    plt.axis('off')
    plt.imshow(build)
    plt.axis('off')
  return plt.show()

# %%
final_search = pd.read_csv('/content/drive/final_captions_24_02_20.csv')

# %%
final_search.head()
# Out:
#                                             image_id  \
# 0  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 1  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 2  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 3  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 4  /content/drive/My Drive/Flickr8k_Dataset/Flick...
#
#                                             captions
# 0  A brown and white dog runs in the grass and ju...
# 1             Two people are racing across a river .
# 2          A rock climber is climbing a rock cliff .
# 3  A man and woman walk together and sitting on a...
# 4  A black puppy is standing inside a small , bro...

# %%
connect = str(input())
# Out:
# dog is running through the snow

# %%
text = 'dog is running'

# %%
conf = final_search.loc[final_search['captions'].str.contains(connect)]

# %%
conf
# Out:
#                                                image_id  \
# 81    /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 107   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 202   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 208   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 228   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# ...                                                 ...
# 7757  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7799  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7844  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7930  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7984  /content/drive/My Drive/Flickr8k_Dataset/Flick...
#
#                                                captions
# 81            A black dog is running through the snow .
# 107   A brown and white dog is running fast through ...
# 202   A dog is running on a dirt path with trees in ...
# 208                  A dog is running on a dirt track .
# 228               The dog is running through the snow .
# ...                                                 ...
# 7757       The white dog is running through the water .
# 7799  A dog is running through a field of grass with...
# 7844  The dog is running on the grass littered with ...
# 7930    A brown dog is running through a grassy field .
# 7984                    A dog is running up the beach .
#
# [216 rows x 2 columns]

# %%
import re

# %%
if len(connect)>10:
  connect = connect
else:
  connect = connect[:5]

# %%
pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.7/dist-packages (0.18.0)

# %%
fuzz.token_sort_ratio(connect,conf)
# Out:
# 0

# %%
conf
# Out:
#                                                image_id  \
# 81    /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 107   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 202   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 208   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 228   /content/drive/My Drive/Flickr8k_Dataset/Flick...
# ...                                                 ...
# 7757  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7799  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7844  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7930  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7984  /content/drive/My Drive/Flickr8k_Dataset/Flick...
#
#                                                captions
# 81            A black dog is running through the snow .
# 107   A brown and white dog is running fast through ...
# 202   A dog is running on a dirt path with trees in ...
# 208                  A dog is running on a dirt track .
# 228               The dog is running through the snow .
# ...                                                 ...
# 7757       The white dog is running through the water .
# 7799  A dog is running through a field of grass with...
# 7844  The dog is running on the grass littered with ...
# 7930    A brown dog is running through a grassy field .
# 7984                    A dog is running up the beach .
#
# [216 rows x 2 columns]

# %%
data = final_search['captions']

# %%
data = pd.DataFrame(data)

# %%
n = len(data)

# %%
connect = str(input())
# Out:
# dog is running through the snow

# %%
a = []
for i in range(n):
  a.append(connect)
final_search['data'] = a

# %%
final_search
# Out:
#                                                image_id  \
# 0     /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 1     /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 2     /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 3     /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 4     /content/drive/My Drive/Flickr8k_Dataset/Flick...
# ...                                                 ...
# 7992  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7993  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7994  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7995  /content/drive/My Drive/Flickr8k_Dataset/Flick...
# 7996  /content/drive/My Drive/Flickr8k_Dataset/Flick...
#
#                                                captions  \
# 0     A brown and white dog runs in the grass and ju...
# 1                Two people are racing across a river .
# 2             A rock climber is climbing a rock cliff .
# 3     A man and woman walk together and sitting on a...
# 4     A black puppy is standing inside a small , bro...
# ...                                                 ...
# 7992  A man in a red jacket skis past a mountain sce...
# 7993   a group of children playing a game in the pool .
# 7994  A mountain climber is descending a snow covere...
# 7995               a horse mascot is in a large dress .
# 7996  A girl in a yellow shirt is walking next to a ...
#
#                                  data
# 0     children is playing in the park
# 1     children is playing in the park
# 2     children is playing in the park
# 3     children is playing in the park
# 4     children is playing in the park
# ...                               ...
# 7992  children is playing in the park
# 7993  children is playing in the park
# 7994  children is playing in the park
# 7995  children is playing in the park
# 7996  children is playing in the park
#
# [7997 rows x 3 columns]

# %%
def get_ratio(row):
    name = row['captions']
    name1 = row['data']
    return fuzz.token_set_ratio(name, name1)
#len(data[data.apply(get_ratio, axis=1) > 70]) / len(df)

# %%
get_ratio(final_search)
# Out:
# 95

# %%
#len(data[data.apply(get_ratio,axis=1)>70])/len(data)

# %%
data = final_search[final_search.apply(get_ratio,axis=1)>90]

# %%
data
# Out:
# Empty DataFrame
# Columns: [image_id, captions, data]
# Index: []

# %%
conf = data['image_id']

# %%
cd /content/

# %%
cp-r "/content/drive/Deepspeech models" speech_models

# %%
cd /content/speech_models/

# %%
ls

# %%
pip install deepspeech==0.6.1
# Out:
# Requirement already satisfied: deepspeech==0.6.1 in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from deepspeech==0.6.1) (1.21.5)

# %%
pip install pydub
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/dist-packages (0.25.1)

# %%
import wave
import numpy as np
import deepspeech
from pydub import AudioSegment

# %%
file_path = '/content/drive/speech/output_graph.pbmm'
Band_width = 500
model = deepspeech.Model(file_path,Band_width)
alpha = 0.7
Beta = 1.85
lm_file = '/content/drive/speech/lm.binary'
trie = '/content/drive/speech/trie'
model.enableDecoderWithLM(lm_file,trie,alpha,Beta)
# Out:
# 0

# %%
def audio_export(filepath,n):
  if n==1:
    audio = AudioSegment.from_mp3('/content/drive/Deepspeech models/tester_common12.mp3')
    audio1 = AudioSegment.from_mp3('/content/drive/Deepspeech models/tester_common13.mp3')
    audio2 = audio+audio1
    file_audio = audio2
    audio3 = AudioSegment.from_mp3(filepath)
    audio4 = file_audio+audio3
    audio5 = audio4.export('test.wav',format='wav')
  if n==2:
    audio = AudioSegment.from_wav('/content/drive/speech/sample2.wav')
    file_audio = AudioSegment.from_wav(filepath)
    audio4 = audio+file_audio
    audio5 = audio4.export('test.wav',format='wav')
  return audio5

# %%
cd /content/
# Out:
# /content

# %%
audio_export('/content/drive/speech/sample1.wav',2)
# Out:
# <_io.BufferedRandom name='test.wav'>

# %%
def audio_rate_set(filepath):
  audio = AudioSegment.from_wav(filepath)
  audio = audio.set_frame_rate(16000)
  audio = audio.export('tester.wav',format='wav')
  return audio

# %%
audio_rate_set('/content/test.wav')
# Out:
# <_io.BufferedRandom name='tester.wav'>

# %%
def text_audio(filepath): 
  audio = wave.open(filepath,'rb')
  frames = audio.getnframes()
  buffer = audio.readframes(frames)
  data = np.frombuffer(buffer, dtype=np.int16)
  text = model.stt(data)
  return text

# %%
text = text_audio('/content/tester.wav')

# %%
text
# Out:
# 'dog is running through the snow'

# %%
texter(text)

# %%
def voice_setting(filename,n):
  data = audio_export(filename,n)
  data2 = audio_rate_set(data)
  return data2

# %%
def voice_setting2(filename):
  text2 = text_audio(filename)
  doc = nlp(text2)
  return texter(text)

# %%
def voice_setting3(filename,n):
  data = voice_setting(filename,n)
  audio = AudioSegment.from_wav(data)
  audio = audio.export('/content/texter.wav',format='wav')
  text =  text_audio('/content/texter.wav')
  #return voice_setting2(data)
  return texter(text)

# %%
def voice_setting5():
  data = voice_setting4()
  data2 = voice_setting('/content/new_file.wav',1)
  audio = AudioSegment.from_wav(data2)
  audio = audio.export('/content/texter.wav',format='wav')
  text =  text_audio('/content/texter.wav')
  #return voice_setting2(data)
  return texter(text)

# %%
voice_setting3('/content/Record (online-voice-recorder.com) (2).mp3',1)

# %%
#audio_export('/content/Record (online-voice-recorder.com) (2).mp3',1)
#audio_rate_set('/content/test.wav')
voice_setting('/content/Record (online-voice-recorder.com) (16).mp3',1)
voice_setting2('/content/tester.wav')

# %%
text

# %%
# !pip install spacy
import spacy
spacy.prefer_gpu()

# %%
nlp = spacy.load('en', disable=['parser', 'ner'])
doc = nlp(text)

# %%
texter(doc)

# %%
text2 = 'This is often not the case for imbalanced classification problems where missing a positive or minority class case is worse than incorrectly classifying an example from the negative or majority class. There are many real-world examples, such as detecting spam email, diagnosing a medical condition, or identifying fraud. In all of these cases, a false negative (missing a case) is worse or more costly than a false positive.Cost-sensitive learning is a subfield of machine learning that takes the costs of prediction errors (and potentially other costs) into account when training a machine learning model. It is a field of study that is closely related to the field of imbalanced learning that is concerned with classification on datasets with a skewed class distribution. As such, many conceptualizations and techniques developed and used for cost-sensitive learning can be adopted for imbalanced classification problems.In this tutorial, you will discover a gentle introduction to cost-sensitive learning for imbalanced classification. After completing this tutorial, you will know:Imbalanced classification problems often value false-positive classification errors differently from false negatives.Cost-sensitive learning is a subfield of machine learning that involves explicitly defining and using costs when training machine learning algorithms.Cost-sensitive techniques may be divided into three groups, including data resampling, algorithm modifications, and ensemble methods.'

# %%
pip install jiwer

# %%
from jiwer import wer

# %%
ground_truth = "hello world i like monhty python what do you mean african or european swallow"
hypothesis = "hello i like python what you mean swallow"

error = wer(ground_truth, hypothesis)

# %%
error

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/data (1).csv')

# %%
df['wav_filename'] = df['wav_filename'].str.replace('/kaggle/working/datavoice/','/content/drive/wavdata/voices/',case=False)

# %%
from tqdm import tqdm

# %%
df['wav_filename'][1]

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
from sklearn.metrics import f1_score

# %%
df['wav_filename'][1:1130]

# %%
df['wav_filename'] = df['wav_filename'].str.replace(' .wav','.wav',case=False)

# %%
a = []
b = []
c = []
for i in tqdm(range(5129,5131)):
  text = text_audio(emh_4['wav_filename'][i])
  text2 = emh_4['Transcript'][i]
  text2 = text2
  error2 = wer(text,text2)
  error = sentence_bleu([text2.split()], text.split(),smoothing_function=False)
  #errpr3 = f1_score(text.split(),text2.split(),average='macro')
  a.append(error)
  b.append(error2)
  #c.append(error3)
wer = sum(b)/len(b)
#f1 = sum(c)/len(c)
blue = sum(a)/len(a)
wacc = (1-wer) * 100

# %%
a

# %%
dataframe = pd.Series(a,name='blue_score')

# %%
dataframe2

# %%
dataframe2 = pd.Series(b,name='WER')

# %%
dataframe2.to_csv('W_1001_3.csv',index=False)

# %%
df['Transcript'][0]

# %%
sum(a)/len(a)

# %%
text = [text.split()]
text2 = text2.split()
sentence_bleu(text,text2)

# %%
wer = sum(a)/len(a)
print(wer)

# %%
Wacc = 1-wer

# %%
text.split()

# %%
text2.split()

# %%
dataframe = pd.read_csv('/content/WER_782.csv')
dataframe2 = pd.read_csv('/content/blue_782.csv')

# %%
wer = sum(dataframe['WER'])/len(dataframe['WER'])
blue = sum(dataframe2['blue_score'])/len(dataframe2['blue_score'])

# %%
wer

# %%
sum(dataframe['WER'])/len(dataframe['WER'])

# %%
colab_requirements = [
    "pip install tensorflow-gpu==2.0.0-beta0",
    "pip install librosa",
    "pip install noisereduce",
    "pip install soundfile",

]
import sys, subprocess

def run_subprocess_command(cmd):
    # run the command
    process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
    # print the output
    for line in process.stdout:
        print(line.decode().strip())

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    for i in colab_requirements:
        run_subprocess_command(i)
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.21.5)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Collecting noisereduce
# Downloading noisereduce-2.0.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from noisereduce) (3.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from noisereduce) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from noisereduce) (4.63.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from noisereduce) (1.21.5)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from noisereduce) (0.8.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from noisereduce) (1.1.0)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (0.51.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (4.4.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (0.10.3.post1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (1.0.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (1.6.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (2.1.9)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (0.2.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa->noisereduce) (21.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa->noisereduce) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa->noisereduce) (0.34.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa->noisereduce) (3.0.7)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->noisereduce) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa->noisereduce) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa->noisereduce) (3.0.4)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa->noisereduce) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->noisereduce) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa->noisereduce) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->noisereduce) (2.21)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->noisereduce) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->noisereduce) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->noisereduce) (3.10.0.2)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-2.0.0
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile) (2.21)

# %%
import IPython
from scipy.io import wavfile
import noisereduce as nr
import soundfile as sf
from noisereduce.generate_noise import band_limited_noise
#import matplotlib.pyplot as plt
import urllib.request
import numpy as np
import io
# %matplotlib inline
#import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read, write
from IPython.display import Audio
from numpy.fft import fft, ifft

# %%
data, rate = sf.read('/content/tester.wav')
data = data

# %%
IPython.display.Audio(data=noise_reduced, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from noisereduce.noisereducev1 import reduce_noise
noise_reduced = reduce_noise(audio_clip=data.astype('float32'),
                                noise_clip=data.astype('float32'),
                                use_tensorflow=True, 
                                verbose=False)

# %%
sf.write('new_file.wav', noise_reduced, rate)

# %%
from IPython.display import Javascript
from google.colab import output
from base64 import b64decode
from io import BytesIO
# !pip -q install pydub
from pydub import AudioSegment

# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from ffmpeg-python) (0.16.0)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %%
from IPython.display import HTML, Audio
from google.colab.output import eval_js
from base64 import b64decode
import numpy as np
from scipy.io.wavfile import read as wav_read, write
import io
import ffmpeg

AUDIO_HTML = """
<script>
var my_div = document.createElement("DIV");
var my_p = document.createElement("P");
var my_btn = document.createElement("BUTTON");
var t = document.createTextNode("Press to start recording");

my_btn.appendChild(t);
//my_p.appendChild(my_btn);
my_div.appendChild(my_btn);
document.body.appendChild(my_div);

var base64data = 0;
var reader;
var recorder, gumStream;
var recordButton = my_btn;

var handleSuccess = function(stream) {
  gumStream = stream;
  var options = {
    //bitsPerSecond: 8000, //chrome seems to ignore, always 48k
    mimeType : 'audio/webm;codecs=opus'
    //mimeType : 'audio/webm;codecs=pcm'
  };            
  //recorder = new MediaRecorder(stream, options);
  recorder = new MediaRecorder(stream);
  recorder.ondataavailable = function(e) {            
    var url = URL.createObjectURL(e.data);
    var preview = document.createElement('audio');
    preview.controls = true;
    preview.src = url;
    document.body.appendChild(preview);

    reader = new FileReader();
    reader.readAsDataURL(e.data); 
    reader.onloadend = function() {
      base64data = reader.result;
      //console.log("Inside FileReader:" + base64data);
    }
  };
  recorder.start();
  };

recordButton.innerText = "Recording... press to stop";

navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);


function toggleRecording() {
  if (recorder && recorder.state == "recording") {
      recorder.stop();
      gumStream.getAudioTracks()[0].stop();
      recordButton.innerText = "Saving the recording... pls wait!"
  }
}

// https://stackoverflow.com/a/951057
function sleep(ms) {
  return new Promise(resolve => setTimeout(resolve, ms));
}

var data = new Promise(resolve=>{
//recordButton.addEventListener("click", toggleRecording);
recordButton.onclick = ()=>{
toggleRecording()

sleep(2000).then(() => {
  // wait 2000ms for the data to be available...
  // ideally this should use something like await...
  //console.log("Inside data:" + base64data)
  resolve(base64data.toString())

});

}
});
      
</script>
"""

def get_audio():
  display(HTML(AUDIO_HTML))
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])
  
  process = (ffmpeg
    .input('pipe:0')
    .output('pipe:1', format='wav')
    .run_async(pipe_stdin=True, pipe_stdout=True, pipe_stderr=True, quiet=True, overwrite_output=True)
  )
  output, err = process.communicate(input=binary)
  
  riff_chunk_size = len(output) - 8
  # Break up the chunk size into four bytes, held in b.
  q = riff_chunk_size
  b = []
  for i in range(4):
      q, r = divmod(q, 256)
      b.append(r)

  # Replace bytes 4:8 in proc.stdout with the actual size of the RIFF chunk.
  riff = output[:4] + bytes(b) + output[8:]

  sr, audio = wav_read(io.BytesIO(riff))

  return audio, sr

# %%
audio, sr = get_audio()
# Out:
# <script>
# var my_div = document.createElement("DIV");
# var my_p = document.createElement("P");
# var my_btn = document.createElement("BUTTON");
# var t = document.createTextNode("Press to start recording");
#
# my_btn.appendChild(t);
# //my_p.appendChild(my_btn);
# my_div.appendChild(my_btn);
# document.body.appendChild(my_div);
#
# var base64data = 0;
# var reader;
# var recorder, gumStream;
# var recordButton = my_btn;
#
# var handleSuccess = function(stream) {
#   gumStream = stream;
#   var options = {
#     //bitsPerSecond: 8000, //chrome seems to ignore, always 48k
#     mimeType : 'audio/webm;codecs=opus'
#     //mimeType : 'audio/webm;codecs=pcm'
#   };
#   //recorder = new MediaRecorder(stream, options);
#   recorder = new MediaRecorder(stream);
#   recorder.ondataavailable = function(e) {
#     var url = URL.createObjectURL(e.data);
#     var preview = document.createElement('audio');
#     preview.controls = true;
#     preview.src = url;
#     document.body.appendChild(preview);
#
#     reader = new FileReader();
#     reader.readAsDataURL(e.data);
#     reader.onloadend = function() {
#       base64data = reader.result;
#       //console.log("Inside FileReader:" + base64data);
#     }
#   };
#   recorder.start();
#   };
#
# recordButton.innerText = "Recording... press to stop";
#
# navigator.mediaDevices.getUserMedia({audio: true}).then(handleSuccess);
#
#
# function toggleRecording() {
#   if (recorder && recorder.state == "recording") {
#       recorder.stop();
#       gumStream.getAudioTracks()[0].stop();
#       recordButton.innerText = "Saving the recording... pls wait!"
#   }
# }
#
# // https://stackoverflow.com/a/951057
# function sleep(ms) {
#   return new Promise(resolve => setTimeout(resolve, ms));
# }
#
# var data = new Promise(resolve=>{
# //recordButton.addEventListener("click", toggleRecording);
# recordButton.onclick = ()=>{
# toggleRecording()
#
# sleep(2000).then(() => {
#   // wait 2000ms for the data to be available...
#   // ideally this should use something like await...
#   //console.log("Inside data:" + base64data)
#   resolve(base64data.toString())
#
# });
#
# }
# });
#
# </script>

# %%
cd /content

# %%
audio.export('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-20d3b2757950> in <module>()
# ----> 1 audio.export('')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'export'

# %%
sf.write('new_file.wav', audio, sr)

# %%
AudioSegment.from_wav('new_file.wav')
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
def voice_setting4():
  audio, sr = get_audio()
  return sf.write('new_file.wav', audio, sr)
