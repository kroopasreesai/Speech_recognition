# %%
pip install deepspeech==0.6.1
# Out:
# ...
#      |████████████████████████████████| 9.6 MB 5.1 MB/s
# ...

# %%
# !apt-get install -qq sox
# Out:
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../2-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../3-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../4-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# ...

# %% [markdown]
# Make a directory 'speech' and upload 3 files inside it: lm.binary, trie and retrained output_graph.pbmm

# %%
import deepspeech

# %%
# !deepspeech --model /content/drive/MyDrive/speech/output_graph.pbmm --lm /content/drive/MyDrive/speech/lm.binary --trie /content/drive/Mydrive/speech/trie --audio /content/drive/MyDrive/speech/sample1.wav
# Out:
# Loading model from file /content/drive/MyDrive/speech/output_graph.pbmm
# TensorFlow: v1.14.0-21-ge77504a
# DeepSpeech: v0.6.1-0-g3df20fe
# 2022-04-10 07:00:00.590151: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# Loaded model in 0.222s.
# Loading language model from files /content/drive/MyDrive/speech/lm.binary /content/drive/Mydrive/speech/trie
# Loaded language model in 28.9s.
# ...
# Running inference.
# for the twentieth time that evening the two men shook hands
# Inference took 5.501s for 14.823s audio file.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
